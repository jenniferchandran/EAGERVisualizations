# %%
import pandas as pd

# %%
df = pd.read_csv('sentiment_final.csv')

# %%
df
# Out:
#        Unnamed: 0             date        Hiker trail name  \
# 0             5.0    1/1/2016 0:00                  Hestia
# 1             6.0    1/1/2016 0:00       Brighty and Wreck
# 2             7.0    1/2/2016 0:00           Brother Blood
# 3            10.0    1/3/2016 0:00                  Hestia
# 4            11.0    1/3/2016 0:00              SIMPLE MAN
# ...           ...              ...                     ...
# 15484     33192.0  10/12/2023 0:00  Flippertree for Autism
# 15485     33212.0   11/9/2023 0:00  Flippertree for Autism
# 15486     33224.0   12/5/2023 0:00  Flippertree for Autism
# 15487     33233.0  12/14/2023 0:00  NARSIL aka Father Time
# 15488     33253.0  12/30/2023 0:00  Flippertree for Autism
#
#                                       Hiker Journal Link  \
# 0      https://www.trailjournals.com//journal/entry/5...
# 1      https://www.trailjournals.com//journal/entry/5...
# 2      https://www.trailjournals.com//journal/entry/5...
# ...

# %%
a = pd.read_csv('Aladdin_data_full')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /Users/user/Desktop/EAGERVisualizations/AladdinKun/a.ipynb Cell 4 line 1
# ----> <a href='vscode-notebook-cell:/Users/user/Desktop/EAGERVisualizations/AladdinKun/a.ipynb#W3sZmlsZQ%3D%3D?line=0'>1</a> a = pd.read_csv('Aladdin_data_full')
#
# ...
